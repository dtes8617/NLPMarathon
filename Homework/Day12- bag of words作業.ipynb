# %% [markdown]
# ## 作業目標：搭建一個bag of words模型

# %% [markdown]
# ---

# %%
import pandas as pd
import nltk
#nltk.download()
import numpy as np
dataset=pd.read_csv('Restaurant_Reviews.tsv',delimiter='\t',quoting=3)
corpus=dataset['Review'].values

# %% [markdown]
# ### 從文本中取出所有單字

# %%
whole_words = []
for sentence in corpus:
    tokenized_sentence = nltk.word_tokenize(sentence)
    for word in tokenized_sentence:
        whole_words.append(word)

# %% [markdown]
# ### 移除重複單字

# %%
whole_words = list(set(whole_words))
print('共有{}個單字'.format(len(whole_words)))
# Out:
# 共有2356個單字

# %% [markdown]
# ### 建立字典使每一個單字有對應數值

# %%
word_index = {}
index_word = {}
n = 0
for word in whole_words:
    word_index[word] = n
    index_word[n] = word
    n +=1

# %%
word_index
# Out:
# {'seen': 0,
#  'due': 1,
#  'believe': 2,
#  'website': 3,
#  'unbelievable': 4,
#  'belly': 5,
#  'cooked': 6,
#  'Hot': 7,
#  'Jamaican': 8,
#  'wife': 9,
#  'OMG': 10,
#  'downtown': 11,
#  'hands-down': 12,
#  'job': 13,
#  'delicious': 14,
#  'WAAAAAAyyyyyyyyyy': 15,
#  'I': 16,
#  'Company': 17,
#  'impressed': 18,
#  'free': 19,
#  'company': 20,
#  'BITCHES': 21,
#  'gristle': 22,
#  'fav': 23,
#  'whenever': 24,
#  '10+': 25,
#  'winner': 26,
#  'MANAGEMENT': 27,
#  'themselves': 28,
#  'ignore': 29,
#  'bad': 30,
#  'AGAIN': 31,
#  'point': 32,
#  'sewer': 33,
#  'And': 34,
#  'promptly': 35,
#  'Bachi': 36,
#  'imaginative': 37,
#  "'ve": 38,
#  'bigger': 39,
#  'Dylan': 40,
#  'groups': 41,
#  'flavourful': 42,
#  'alone': 43,
#  'small': 44,
#  'Any': 45,
#  'shoe': 46,
#  'low-key': 47,
#  'waited': 48,
#  'Anyways': 49,
#  'apart': 50,
#  'unexperienced': 51,
#  'disapppointment': 52,
#  'original': 53,
#  'Much': 54,
#  'movies': 55,
#  'Otto': 56,
#  'Delicious': 57,
#  'less': 58,
#  'Up': 59,
#  'attentive': 60,
#  'Give': 61,
#  'over': 62,
#  'common': 63,
#  'gem': 64,
#  'Stars': 65,
#  'new': 66,
#  'sandwiches': 67,
#  'skimp': 68,
#  'working/eating': 69,
#  'damn': 70,
#  'eggs': 71,
#  'saffron': 72,
#  'down': 73,
#  'life': 74,
#  'waiting': 75,
#  'OK': 76,
#  'exceeding': 77,
#  'relax': 78,
#  'smeared': 79,
#  'dishes': 80,
#  'Mary': 81,
#  'still': 82,
#  'final': 83,
#  'saying': 84,
#  'Im': 85,
#  'That': 86,
#  'They': 87,
#  'Please': 88,
#  'Lastly': 89,
#  'Host': 90,
#  'dripping': 91,
#  'combo': 92,
#  'simply': 93,
#  'businesses': 94,
#  'stars': 95,
#  'hummus': 96,
#  'sugary': 97,
#  'Terrible': 98,
#  'Ordered': 99,
#  'bakery': 100,
#  'ambience': 101,
#  'Customer': 102,
#  'doing': 103,
#  'tuna': 104,
#  'Boy': 105,
#  'gratuity': 106,
#  '.': 107,
#  'As': 108,
#  'Come': 109,
#  'awkwardly': 110,
#  'gave': 111,
#  'Worst': 112,
#  'must': 113,
#  'its': 114,
#  'cheek': 115,
#  'hits': 116,
#  'more': 117,
#  'watch': 118,
#  'smells': 119,
#  'walked': 120,
#  'hate': 121,
#  'By': 122,
#  'Total': 123,
#  'fast': 124,
#  'array': 125,
#  'when': 126,
#  '2007': 127,
#  'requested': 128,
#  'hole': 129,
#  'experienced': 130,
#  'decision': 131,
#  'entire': 132,
#  'Hiro': 133,
#  'favor': 134,
#  'pan': 135,
#  'Cartel': 136,
#  'garden': 137,
#  'beateous': 138,
#  'petrified': 139,
#  'waitresses': 140,
#  'Palm': 141,
#  'Risotto': 142,
#  'Favorite': 143,
#  'actually': 144,
#  'barely': 145,
#  'potatoes': 146,
#  'ate': 147,
#  'Excalibur': 148,
#  'piece': 149,
#  'Ninja': 150,
#  'Jeff': 151,
#  'mayo': 152,
#  'dinners': 153,
#  'awful': 154,
#  'am': 155,
#  'pink': 156,
#  'craving': 157,
#  'mixed': 158,
#  'make': 159,
#  'personable': 160,
#  'happier': 161,
#  'giving': 162,
#  'yay': 163,
#  'car': 164,
#  'to-go': 165,
#  'baklava': 166,
#  'disappoint': 167,
#  'HAD': 168,
#  'but': 169,
#  'me': 170,
#  'FORWARD': 171,
#  'positive': 172,
#  'far': 173,
#  'Edinburgh': 174,
#  'next': 175,
#  'Buldogis': 176,
#  'Caesar': 177,
#  'Paying': 178,
#  'pop': 179,
#  'Yelpers': 180,
#  'bought': 181,
#  '3/4ths': 182,
#  'Flower': 183,
#  'pictures': 184,
#  'setting': 185,
#  'Mellow': 186,
#  'judging': 187,
#  'Lemon': 188,
#  's': 189,
#  'Stopped': 190,
#  'rings': 191,
#  'longer': 192,
#  'melt': 193,
#  'All': 194,
#  'customize': 195,
#  'ordered': 196,
#  'busy': 197,
#  'rather': 198,
#  'Lox': 199,
#  'star': 200,
#  'She': 201,
#  'tragedy': 202,
#  'Ambience': 203,
#  'dropped': 204,
#  'court': 205,
#  'imagined': 206,
#  'moods': 207,
#  'green': 208,
#  'screwed': 209,
#  'ache': 210,
#  'tried': 211,
#  'pleasant': 212,
#  'flair': 213,
#  'stinks': 214,
#  'strange': 215,
#  'style': 216,
#  'joke': 217,
#  'servers': 218,
#  'concept': 219,
#  '.very': 220,
#  'Magazine': 221,
#  'baby': 222,
#  'On': 223,
#  'Furthermore': 224,
#  'containers': 225,
#  'Pho': 226,
#  'maintaining': 227,
#  'staying': 228,
#  'Casino': 229,
#  'item': 230,
#  'tables': 231,
#  'MGM': 232,
#  'placed': 233,
#  'decent': 234,
#  'count': 235,
#  'ended': 236,
#  'chefs': 237,
#  'southwest': 238,
#  'fan': 239,
#  'Francisco': 240,
#  'Penne': 241,
#  'wine': 242,
#  'restaurant': 243,
#  '40min': 244,
#  'cheesecurds': 245,
#  'Some': 246,
#  'Would': 247,
#  'undercooked': 248,
#  'interior': 249,
#  'handmade': 250,
#  'pleasure': 251,
#  'Dos': 252,
#  'indoor': 253,
#  'dirty': 254,
#  'sub': 255,
#  'saving': 256,
#  'Insults': 257,
#  'problem': 258,
#  'Philadelphia': 259,
#  'prepared': 260,
#  'cash': 261,
#  'Tucson': 262,
#  'several': 263,
#  'Google': 264,
#  'Be': 265,
#  'theft': 266,
#  'speedy': 267,
#  'big': 268,
#  'bite': 269,
#  'Perfect': 270,
#  'Everything': 271,
#  'TOLD': 272,
#  'cause': 273,
#  'sitting': 274,
#  'tolerance': 275,
#  'soooo': 276,
#  'vain': 277,
#  'delight': 278,
#  'special': 279,
#  'thats': 280,
#  'Las': 281,
#  'business': 282,
#  '2': 283,
#  'refreshing': 284,
#  'five': 285,
#  'thing': 286,
#  'nude': 287,
#  'fucking': 288,
#  'tummy': 289,
#  'Every': 290,
#  'Bouchon': 291,
#  'forgetting': 292,
#  'heart': 293,
#  'chickens': 294,
#  'loyal': 295,
#  'personally': 296,
#  'means': 297,
#  'best': 298,
#  'TV': 299,
#  'mortified': 300,
#  'correction': 301,
#  'biggest': 302,
#  'shots': 303,
#  'trap': 304,
#  'myself': 305,
#  'disbelief': 306,
#  'disappointing': 307,
#  'turn': 308,
#  'at': 309,
#  'case': 310,
#  'witnessed': 311,
#  'hair': 312,
#  'honest': 313,
#  'real': 314,
#  'thought': 315,
#  '10': 316,
#  'nigiri': 317,
#  'From': 318,
#  ')': 319,
#  'hated': 320,
#  'rushed': 321,
#  'surprised': 322,
#  'years': 323,
#  'two': 324,
#  'front': 325,
#  'publicly': 326,
#  'transcendant': 327,
#  'refill': 328,
#  'owned': 329,
#  'Albondigas': 330,
#  'sat': 331,
#  'deserves': 332,
#  'filling': 333,
#  'texture': 334,
#  'say': 335,
#  'Elk': 336,
#  'ridiculous': 337,
#  'Mom': 338,
#  'thanks': 339,
#  'everyone': 340,
#  'wash': 341,
#  'came': 342,
#  'human': 343,
#  'us': 344,
#  'check': 345,
#  'military': 346,
#  'tastings': 347,
#  'without': 348,
#  '17': 349,
#  'begin': 350,
#  'dude': 351,
#  'Damn': 352,
#  'person': 353,
#  'wasting': 354,
#  'stomach': 355,
#  'Kabuki': 356,
#  'judge': 357,
#  'describing': 358,
#  'teamwork': 359,
#  'touched': 360,
#  'Hunan': 361,
#  'cocktails': 362,
#  'hopes': 363,
#  'eyed': 364,
#  'crispy': 365,
#  'finger': 366,
#  'covered': 367,
#  'circumstances': 368,
#  'voted': 369,
#  'chocolate': 370,
#  'went': 371,
#  'cakes': 372,
#  'party': 373,
#  'relleno': 374,
#  'going': 375,
#  'wave': 376,
#  'boxes': 377,
#  'family': 378,
#  'Aria': 379,
#  'deliver': 380,
#  'three': 381,
#  'succulent': 382,
#  'great': 383,
#  'portion': 384,
#  'mile': 385,
#  'jalapeno': 386,
#  'via': 387,
#  'generic': 388,
#  '70+': 389,
#  'thrilled': 390,
#  'patty': 391,
#  'dessert': 392,
#  'cavier': 393,
#  'Third': 394,
#  'one': 395,
#  'Extremely': 396,
#  'exquisite': 397,
#  'cannoli': 398,
#  'mesquite': 399,
#  'meatloaf': 400,
#  'receives': 401,
#  'petty': 402,
#  'Both': 403,
#  'angry': 404,
#  'Japanese': 405,
#  'rate': 406,
#  'High-quality': 407,
#  'gas': 408,
#  '20': 409,
#  'Yama': 410,
#  'late': 411,
#  'short': 412,
#  'dates': 413,
#  'moz': 414,
#  'gotten': 415,
#  'whether': 416,
#  'town': 417,
#  'coziness': 418,
#  'average': 419,
#  'high': 420,
#  'way': 421,
#  'Bloody': 422,
#  'really': 423,
#  'returned': 424,
#  'mozzarella': 425,
#  'some': 426,
#  'dough': 427,
#  'Over': 428,
#  'restaraunt': 429,
#  'Standard': 430,
#  'Spend': 431,
#  'Thoroughly': 432,
#  'There': 433,
#  'top': 434,
#  'reasonably': 435,
#  'Luke': 436,
#  'Phoenix': 437,
#  'you': 438,
#  'slow': 439,
#  'old': 440,
#  'end': 441,
#  'mein': 442,
#  'Poor': 443,
#  'airline': 444,
#  'much': 445,
#  'sound': 446,
#  'suggestions': 447,
#  'mall': 448,
#  'drink': 449,
#  'ranch': 450,
#  'Great': 451,
#  'GO': 452,
#  'Noca': 453,
#  'highly': 454,
#  'Update': 455,
#  'inviting': 456,
#  '..there': 457,
#  'grilled': 458,
#  'cheap': 459,
#  'slaw': 460,
#  'wow': 461,
#  'server': 462,
#  'sugar': 463,
#  'fondue': 464,
#  'anymore': 465,
#  'non-fancy': 466,
#  'possible': 467,
#  'huevos': 468,
#  'instantly': 469,
#  'crazy': 470,
#  'promise': 471,
#  'occasions': 472,
#  'just': 473,
#  '?': 474,
#  'flavor': 475,
#  'strings': 476,
#  'before': 477,
#  'pulled': 478,
#  'Ians': 479,
#  'portions': 480,
#  '1979': 481,
#  'quaint': 482,
#  'frozen': 483,
#  'dedicated': 484,
#  'absolutely': 485,
#  'ball': 486,
#  'Pizza': 487,
#  'serve': 488,
#  'why': 489,
#  'specials': 490,
#  'Hawaiian': 491,
#  'tater': 492,
#  'saganaki': 493,
#  'uploaded': 494,
#  'glass': 495,
#  'salt': 496,
#  'she': 497,
#  'bamboo': 498,
#  'NONE': 499,
#  'week': 500,
#  'mouths': 501,
#  'wish': 502,
#  'cow': 503,
#  'Green': 504,
#  'disaster': 505,
#  'blows': 506,
#  'imagination': 507,
#  'sad': 508,
#  'Rock': 509,
#  'evening': 510,
#  'worse': 511,
#  'foods': 512,
#  'Ironman': 513,
#  'lover': 514,
#  'rave': 515,
#  'limited': 516,
#  'juice..': 517,
#  'perfect': 518,
#  'brick': 519,
#  'freaking': 520,
#  'Really': 521,
#  'vanilla': 522,
#  'water': 523,
#  'spots': 524,
#  'To': 525,
#  'typical': 526,
#  'figured': 527,
#  'Took': 528,
#  'gyros': 529,
#  'walls': 530,
#  'refrained': 531,
#  'beautiful': 532,
#  'what': 533,
#  'usual': 534,
#  'letdown': 535,
#  'expanded': 536,
#  'reminded': 537,
#  'occasional': 538,
#  'Appetite': 539,
#  'yummy': 540,
#  'mouth': 541,
#  'HAVE': 542,
#  'OWNERS': 543,
#  'dog': 544,
#  'elegantly': 545,
#  'untoasted': 546,
#  'Phenomenal': 547,
#  'showed': 548,
#  'no': 549,
#  'dead': 550,
#  'FLY': 551,
#  'meh': 552,
#  'Anyway': 553,
#  'powdered': 554,
#  'disgrace': 555,
#  'holiday': 556,
#  'cuisine': 557,
#  'larger': 558,
#  'Fantastic': 559,
#  'Taco': 560,
#  'quit': 561,
#  'Mediocre': 562,
#  'poisoning': 563,
#  'selection': 564,
#  'hard': 565,
#  'classic': 566,
#  'law': 567,
#  'grandmother': 568,
#  'tasteless': 569,
#  'wonderful': 570,
#  'Steak': 571,
#  'Dog': 572,
#  '1.5lb': 573,
#  'ourselves': 574,
#  'Khao': 575,
#  'leftover': 576,
#  'night': 577,
#  'idea': 578,
#  'prime': 579,
#  'croutons': 580,
#  'so': 581,
#  'Level': 582,
#  'oysters': 583,
#  'somehow': 584,
#  'accident': 585,
#  'truly': 586,
#  'Prices': 587,
#  'i': 588,
#  'FLAVOR': 589,
#  'grow': 590,
#  'location': 591,
#  'delights': 592,
#  'salty': 593,
#  'Chinese': 594,
#  'vegetables': 595,
#  'flat-lined': 596,
#  'seems': 597,
#  'terrific': 598,
#  'choose': 599,
#  'fail': 600,
#  'away': 601,
#  'boyfriend': 602,
#  'worst': 603,
#  'mary': 604,
#  'nut': 605,
#  'extensive': 606,
#  'ensued': 607,
#  'accordingly': 608,
#  'Costco': 609,
#  'checked': 610,
#  'killer': 611,
#  'need': 612,
#  'have': 613,
#  'apparently': 614,
#  'rubber': 615,
#  'martini': 616,
#  'atmosphere.1': 617,
#  'wanted': 618,
#  'hostess': 619,
#  'understand': 620,
#  'discount': 621,
#  'Indian': 622,
#  'rich': 623,
#  'passed': 624,
#  'equally': 625,
#  'fear': 626,
#  'stir': 627,
#  'arrives': 628,
#  'edible': 629,
#  'RUDE': 630,
#  'bird': 631,
#  'feeling': 632,
#  'NASTY': 633,
#  'sause': 634,
#  'not': 635,
#  'over-whelm': 636,
#  'expected': 637,
#  'roasted': 638,
#  'bits': 639,
#  'Disappointed': 640,
#  'pricing': 641,
#  'give': 642,
#  'lawyers': 643,
#  'nice': 644,
#  'Plus': 645,
#  'gyro': 646,
#  'drag': 647,
#  'treated': 648,
#  'group': 649,
#  'UNREAL': 650,
#  'past': 651,
#  'long': 652,
#  'once': 653,
#  'biscuits': 654,
#  'complete': 655,
#  'Vegetarian': 656,
#  'Egg': 657,
#  'value': 658,
#  'WAY': 659,
#  'obviously': 660,
#  'events': 661,
#  'vegan/veggie': 662,
#  '.the': 663,
#  'attention': 664,
#  '%': 665,
#  'seriously': 666,
#  'unprofessional': 667,
#  'hours': 668,
#  'nearly': 669,
#  'Pita': 670,
#  'cocktail': 671,
#  'prepare': 672,
#  'Delight': 673,
#  'Fridays': 674,
#  'soooooo': 675,
#  'visited': 676,
#  'deeply': 677,
#  'hottest': 678,
#  'needed': 679,
#  'house': 680,
#  'Then': 681,
#  'worth': 682,
#  'excellent': 683,
#  'dispenser': 684,
#  'SCREAMS': 685,
#  'rarely': 686,
#  'accountant': 687,
#  'while': 688,
#  'being': 689,
#  'Bussell': 690,
#  'Seriously': 691,
#  'selections': 692,
#  'liking': 693,
#  'Hands': 694,
#  'crêpe': 695,
#  'stepped': 696,
#  'unwrapped': 697,
#  'meat': 698,
#  'slices': 699,
#  'disagree': 700,
#  'space': 701,
#  'sick': 702,
#  'interesting': 703,
#  'Breeze': 704,
#  'name': 705,
#  'Everyone': 706,
#  'likes': 707,
#  'Crema': 708,
#  'Unfortunately': 709,
#  'falafels': 710,
#  'beers': 711,
#  'FREEZING': 712,
#  'expect': 713,
#  'Back': 714,
#  'incredible': 715,
#  'marrow': 716,
#  'proclaimed': 717,
#  'dining': 718,
#  'charming': 719,
#  'block': 720,
#  'bites': 721,
#  'curry': 722,
#  'anything': 723,
#  'tailored': 724,
#  'Kind': 725,
#  '..ohhh': 726,
#  'insulted': 727,
#  'Caballero': 728,
#  'first': 729,
#  'few': 730,
#  'fresh': 731,
#  'soundtrack': 732,
#  'DELICIOUS': 733,
#  'treat': 734,
#  'Magic': 735,
#  'burgers': 736,
#  'beer': 737,
#  'Cute': 738,
#  'exceptional': 739,
#  'had': 740,
#  'half': 741,
#  'Wo': 742,
#  'provides': 743,
#  'wontons': 744,
#  'overall': 745,
#  'mains': 746,
#  'must-stop': 747,
#  'Veggitarian': 748,
#  'FANTASTIC': 749,
#  'color': 750,
#  'satisfied': 751,
#  'every': 752,
#  'Halibut': 753,
#  'One': 754,
#  'gluten': 755,
#  'food/service': 756,
#  'seasoning': 757,
#  'courteous': 758,
#  'Yeah': 759,
#  'worker': 760,
#  'peanuts': 761,
#  'cost': 762,
#  'look': 763,
#  '35': 764,
#  'been-stepped-in-and-tracked-everywhere': 765,
#  'carpaccio': 766,
#  'turkey': 767,
#  'live': 768,
#  'hoping': 769,
#  'dried': 770,
#  'Cod': 771,
#  'very': 772,
#  '100': 773,
#  'chicken': 774,
#  'restaurants': 775,
#  'excuse': 776,
#  'Area': 777,
#  'section': 778,
#  'clue': 779,
#  'fiancé': 780,
#  'AND': 781,
#  'extremely': 782,
#  'reading': 783,
#  'spice': 784,
#  'place': 785,
#  'particular': 786,
#  'pastry': 787,
#  'bartender': 788,
#  'etc': 789,
#  'gold': 790,
#  'papers': 791,
#  'drive': 792,
#  'affordable': 793,
#  'Based': 794,
#  'part': 795,
#  'since': 796,
#  'REALLY': 797,
#  'find': 798,
#  'neighborhood': 799,
#  'hand': 800,
#  'Could': 801,
#  'says': 802,
#  'fuzzy': 803,
#  'rudely': 804,
#  'friend': 805,
#  'packed': 806,
#  'break': 807,
#  'running': 808,
#  'Del': 809,
#  'reservation': 810,
#  'third': 811,
#  'Maine': 812,
#  'Wienerschnitzel': 813,
#  'Overpriced': 814,
#  'spotty': 815,
#  'mouthful': 816,
#  'Maria': 817,
#  'THIS': 818,
#  'cooking': 819,
#  'email': 820,
#  'middle': 821,
#  'missing': 822,
#  'cover': 823,
#  'daily': 824,
#  'Service-check': 825,
#  'funny': 826,
#  'A': 827,
#  'After': 828,
#  'close': 829,
#  'fries': 830,
#  'held': 831,
#  'AN': 832,
#  'NOT': 833,
#  'fry': 834,
#  'pasta': 835,
#  'capers': 836,
#  'refried': 837,
#  'companions': 838,
#  'closed': 839,
#  'bloodiest': 840,
#  'crepe': 841,
#  '/hand': 842,
#  'inexpensive': 843,
#  'upgrading': 844,
#  'rinse': 845,
#  'up': 846,
#  'apologize': 847,
#  'Soi': 848,
#  'these': 849,
#  'plus': 850,
#  'send': 851,
#  'mussels': 852,
#  'black': 853,
#  'experience': 854,
#  'go': 855,
#  'wall': 856,
#  'under-services': 857,
#  'auju': 858,
#  'giant': 859,
#  'blandest': 860,
#  'Check': 861,
#  'bread': 862,
#  'meet': 863,
#  'peas': 864,
#  'dish': 865,
#  'although': 866,
#  'sucked': 867,
#  'tenders': 868,
#  'vibe': 869,
#  'legit': 870,
#  'bagels': 871,
#  'Waited': 872,
#  'fabulous': 873,
#  'raspberry': 874,
#  'condiment': 875,
#  'warnings': 876,
#  'customers': 877,
#  'please': 878,
#  'served': 879,
#  'oh': 880,
#  'Sprouts': 881,
#  'finish': 882,
#  'gross': 883,
#  'Baseball': 884,
#  'teeth': 885,
#  'Rick': 886,
#  'Blah': 887,
#  'stop': 888,
#  'we': 889,
#  'starving': 890,
#  'out': 891,
#  'today': 892,
#  'tea': 893,
#  'smaller': 894,
#  'got': 895,
#  'time': 896,
#  'until': 897,
#  'surprise': 898,
#  'piano': 899,
#  'said': 900,
#  'lot': 901,
#  '-My': 902,
#  'Seat': 903,
#  'stupid': 904,
#  'would': 905,
#  'negligent': 906,
#  'satifying': 907,
#  'bit': 908,
#  'who': 909,
#  'hour': 910,
#  'burned': 911,
#  'pepper': 912,
#  'be': 913,
#  'probably': 914,
#  'serivce': 915,
#  'imagine': 916,
#  'felt': 917,
#  'properly': 918,
#  'charcoal': 919,
#  'bellies': 920,
#  'kind': 921,
#  'zero': 922,
#  'connoisseur': 923,
#  'comfortable': 924,
#  'spot': 925,
#  'highlighted': 926,
#  'cook': 927,
#  'But': 928,
#  'colder': 929,
#  'talk': 930,
#  'coffee': 931,
#  'Paradise': 932,
#  'plain': 933,
#  'low': 934,
#  'sub-par': 935,
#  'opinion': 936,
#  'humiliated': 937,
#  'Sat': 938,
#  'OVERPRICED': 939,
#  'crisp': 940,
#  'char': 941,
#  'horrible': 942,
#  'Very': 943,
#  '8': 944,
#  'summarize': 945,
#  'Friend': 946,
#  'people': 947,
#  'memory': 948,
#  'providing': 949,
#  'beans': 950,
#  'should': 951,
#  'opposed': 952,
#  'here': 953,
#  'Experience': 954,
#  'steakhouse': 955,
#  'Long': 956,
#  'downside': 957,
#  'especially': 958,
#  'Disappointing': 959,
#  'too': 960,
#  'modern': 961,
#  'left': 962,
#  'Nice': 963,
#  'wasted': 964,
#  'truffle': 965,
#  '.off': 966,
#  'wide': 967,
#  'extra': 968,
#  'complaints': 969,
#  'poor': 970,
#  'outdoor': 971,
#  'An': 972,
#  'Joey': 973,
#  'man': 974,
#  'WEAK': 975,
#  'largely': 976,
#  'least': 977,
#  'monster': 978,
#  'thru': 979,
#  'lettuce': 980,
#  'HOUR': 981,
#  'off': 982,
#  'lightly': 983,
#  'beat': 984,
#  'extraordinary': 985,
#  'Lordy': 986,
#  'ESTABLISHMENT': 987,
#  'Hard': 988,
#  'ratio': 989,
#  'greens': 990,
#  'Bland': 991,
#  'red': 992,
#  'Cape': 993,
#  '*': 994,
#  'Bellagio': 995,
#  'disgust': 996,
#  'nicest': 997,
#  'fare': 998,
#  'flavorful': 999,
#  ...}

# %%
index_word
# Out:
# {0: 'seen',
#  1: 'due',
#  2: 'believe',
#  3: 'website',
#  4: 'unbelievable',
#  5: 'belly',
#  6: 'cooked',
#  7: 'Hot',
#  8: 'Jamaican',
#  9: 'wife',
#  10: 'OMG',
#  11: 'downtown',
#  12: 'hands-down',
#  13: 'job',
#  14: 'delicious',
#  15: 'WAAAAAAyyyyyyyyyy',
#  16: 'I',
#  17: 'Company',
#  18: 'impressed',
#  19: 'free',
#  20: 'company',
#  21: 'BITCHES',
#  22: 'gristle',
#  23: 'fav',
#  24: 'whenever',
#  25: '10+',
#  26: 'winner',
#  27: 'MANAGEMENT',
#  28: 'themselves',
#  29: 'ignore',
#  30: 'bad',
#  31: 'AGAIN',
#  32: 'point',
#  33: 'sewer',
#  34: 'And',
#  35: 'promptly',
#  36: 'Bachi',
#  37: 'imaginative',
#  38: "'ve",
#  39: 'bigger',
#  40: 'Dylan',
#  41: 'groups',
#  42: 'flavourful',
#  43: 'alone',
#  44: 'small',
#  45: 'Any',
#  46: 'shoe',
#  47: 'low-key',
#  48: 'waited',
#  49: 'Anyways',
#  50: 'apart',
#  51: 'unexperienced',
#  52: 'disapppointment',
#  53: 'original',
#  54: 'Much',
#  55: 'movies',
#  56: 'Otto',
#  57: 'Delicious',
#  58: 'less',
#  59: 'Up',
#  60: 'attentive',
#  61: 'Give',
#  62: 'over',
#  63: 'common',
#  64: 'gem',
#  65: 'Stars',
#  66: 'new',
#  67: 'sandwiches',
#  68: 'skimp',
#  69: 'working/eating',
#  70: 'damn',
#  71: 'eggs',
#  72: 'saffron',
#  73: 'down',
#  74: 'life',
#  75: 'waiting',
#  76: 'OK',
#  77: 'exceeding',
#  78: 'relax',
#  79: 'smeared',
#  80: 'dishes',
#  81: 'Mary',
#  82: 'still',
#  83: 'final',
#  84: 'saying',
#  85: 'Im',
#  86: 'That',
#  87: 'They',
#  88: 'Please',
#  89: 'Lastly',
#  90: 'Host',
#  91: 'dripping',
#  92: 'combo',
#  93: 'simply',
#  94: 'businesses',
#  95: 'stars',
#  96: 'hummus',
#  97: 'sugary',
#  98: 'Terrible',
#  99: 'Ordered',
#  100: 'bakery',
#  101: 'ambience',
#  102: 'Customer',
#  103: 'doing',
#  104: 'tuna',
#  105: 'Boy',
#  106: 'gratuity',
#  107: '.',
#  108: 'As',
#  109: 'Come',
#  110: 'awkwardly',
#  111: 'gave',
#  112: 'Worst',
#  113: 'must',
#  114: 'its',
#  115: 'cheek',
#  116: 'hits',
#  117: 'more',
#  118: 'watch',
#  119: 'smells',
#  120: 'walked',
#  121: 'hate',
#  122: 'By',
#  123: 'Total',
#  124: 'fast',
#  125: 'array',
#  126: 'when',
#  127: '2007',
#  128: 'requested',
#  129: 'hole',
#  130: 'experienced',
#  131: 'decision',
#  132: 'entire',
#  133: 'Hiro',
#  134: 'favor',
#  135: 'pan',
#  136: 'Cartel',
#  137: 'garden',
#  138: 'beateous',
#  139: 'petrified',
#  140: 'waitresses',
#  141: 'Palm',
#  142: 'Risotto',
#  143: 'Favorite',
#  144: 'actually',
#  145: 'barely',
#  146: 'potatoes',
#  147: 'ate',
#  148: 'Excalibur',
#  149: 'piece',
#  150: 'Ninja',
#  151: 'Jeff',
#  152: 'mayo',
#  153: 'dinners',
#  154: 'awful',
#  155: 'am',
#  156: 'pink',
#  157: 'craving',
#  158: 'mixed',
#  159: 'make',
#  160: 'personable',
#  161: 'happier',
#  162: 'giving',
#  163: 'yay',
#  164: 'car',
#  165: 'to-go',
#  166: 'baklava',
#  167: 'disappoint',
#  168: 'HAD',
#  169: 'but',
#  170: 'me',
#  171: 'FORWARD',
#  172: 'positive',
#  173: 'far',
#  174: 'Edinburgh',
#  175: 'next',
#  176: 'Buldogis',
#  177: 'Caesar',
#  178: 'Paying',
#  179: 'pop',
#  180: 'Yelpers',
#  181: 'bought',
#  182: '3/4ths',
#  183: 'Flower',
#  184: 'pictures',
#  185: 'setting',
#  186: 'Mellow',
#  187: 'judging',
#  188: 'Lemon',
#  189: 's',
#  190: 'Stopped',
#  191: 'rings',
#  192: 'longer',
#  193: 'melt',
#  194: 'All',
#  195: 'customize',
#  196: 'ordered',
#  197: 'busy',
#  198: 'rather',
#  199: 'Lox',
#  200: 'star',
#  201: 'She',
#  202: 'tragedy',
#  203: 'Ambience',
#  204: 'dropped',
#  205: 'court',
#  206: 'imagined',
#  207: 'moods',
#  208: 'green',
#  209: 'screwed',
#  210: 'ache',
#  211: 'tried',
#  212: 'pleasant',
#  213: 'flair',
#  214: 'stinks',
#  215: 'strange',
#  216: 'style',
#  217: 'joke',
#  218: 'servers',
#  219: 'concept',
#  220: '.very',
#  221: 'Magazine',
#  222: 'baby',
#  223: 'On',
#  224: 'Furthermore',
#  225: 'containers',
#  226: 'Pho',
#  227: 'maintaining',
#  228: 'staying',
#  229: 'Casino',
#  230: 'item',
#  231: 'tables',
#  232: 'MGM',
#  233: 'placed',
#  234: 'decent',
#  235: 'count',
#  236: 'ended',
#  237: 'chefs',
#  238: 'southwest',
#  239: 'fan',
#  240: 'Francisco',
#  241: 'Penne',
#  242: 'wine',
#  243: 'restaurant',
#  244: '40min',
#  245: 'cheesecurds',
#  246: 'Some',
#  247: 'Would',
#  248: 'undercooked',
#  249: 'interior',
#  250: 'handmade',
#  251: 'pleasure',
#  252: 'Dos',
#  253: 'indoor',
#  254: 'dirty',
#  255: 'sub',
#  256: 'saving',
#  257: 'Insults',
#  258: 'problem',
#  259: 'Philadelphia',
#  260: 'prepared',
#  261: 'cash',
#  262: 'Tucson',
#  263: 'several',
#  264: 'Google',
#  265: 'Be',
#  266: 'theft',
#  267: 'speedy',
#  268: 'big',
#  269: 'bite',
#  270: 'Perfect',
#  271: 'Everything',
#  272: 'TOLD',
#  273: 'cause',
#  274: 'sitting',
#  275: 'tolerance',
#  276: 'soooo',
#  277: 'vain',
#  278: 'delight',
#  279: 'special',
#  280: 'thats',
#  281: 'Las',
#  282: 'business',
#  283: '2',
#  284: 'refreshing',
#  285: 'five',
#  286: 'thing',
#  287: 'nude',
#  288: 'fucking',
#  289: 'tummy',
#  290: 'Every',
#  291: 'Bouchon',
#  292: 'forgetting',
#  293: 'heart',
#  294: 'chickens',
#  295: 'loyal',
#  296: 'personally',
#  297: 'means',
#  298: 'best',
#  299: 'TV',
#  300: 'mortified',
#  301: 'correction',
#  302: 'biggest',
#  303: 'shots',
#  304: 'trap',
#  305: 'myself',
#  306: 'disbelief',
#  307: 'disappointing',
#  308: 'turn',
#  309: 'at',
#  310: 'case',
#  311: 'witnessed',
#  312: 'hair',
#  313: 'honest',
#  314: 'real',
#  315: 'thought',
#  316: '10',
#  317: 'nigiri',
#  318: 'From',
#  319: ')',
#  320: 'hated',
#  321: 'rushed',
#  322: 'surprised',
#  323: 'years',
#  324: 'two',
#  325: 'front',
#  326: 'publicly',
#  327: 'transcendant',
#  328: 'refill',
#  329: 'owned',
#  330: 'Albondigas',
#  331: 'sat',
#  332: 'deserves',
#  333: 'filling',
#  334: 'texture',
#  335: 'say',
#  336: 'Elk',
#  337: 'ridiculous',
#  338: 'Mom',
#  339: 'thanks',
#  340: 'everyone',
#  341: 'wash',
#  342: 'came',
#  343: 'human',
#  344: 'us',
#  345: 'check',
#  346: 'military',
#  347: 'tastings',
#  348: 'without',
#  349: '17',
#  350: 'begin',
#  351: 'dude',
#  352: 'Damn',
#  353: 'person',
#  354: 'wasting',
#  355: 'stomach',
#  356: 'Kabuki',
#  357: 'judge',
#  358: 'describing',
#  359: 'teamwork',
#  360: 'touched',
#  361: 'Hunan',
#  362: 'cocktails',
#  363: 'hopes',
#  364: 'eyed',
#  365: 'crispy',
#  366: 'finger',
#  367: 'covered',
#  368: 'circumstances',
#  369: 'voted',
#  370: 'chocolate',
#  371: 'went',
#  372: 'cakes',
#  373: 'party',
#  374: 'relleno',
#  375: 'going',
#  376: 'wave',
#  377: 'boxes',
#  378: 'family',
#  379: 'Aria',
#  380: 'deliver',
#  381: 'three',
#  382: 'succulent',
#  383: 'great',
#  384: 'portion',
#  385: 'mile',
#  386: 'jalapeno',
#  387: 'via',
#  388: 'generic',
#  389: '70+',
#  390: 'thrilled',
#  391: 'patty',
#  392: 'dessert',
#  393: 'cavier',
#  394: 'Third',
#  395: 'one',
#  396: 'Extremely',
#  397: 'exquisite',
#  398: 'cannoli',
#  399: 'mesquite',
#  400: 'meatloaf',
#  401: 'receives',
#  402: 'petty',
#  403: 'Both',
#  404: 'angry',
#  405: 'Japanese',
#  406: 'rate',
#  407: 'High-quality',
#  408: 'gas',
#  409: '20',
#  410: 'Yama',
#  411: 'late',
#  412: 'short',
#  413: 'dates',
#  414: 'moz',
#  415: 'gotten',
#  416: 'whether',
#  417: 'town',
#  418: 'coziness',
#  419: 'average',
#  420: 'high',
#  421: 'way',
#  422: 'Bloody',
#  423: 'really',
#  424: 'returned',
#  425: 'mozzarella',
#  426: 'some',
#  427: 'dough',
#  428: 'Over',
#  429: 'restaraunt',
#  430: 'Standard',
#  431: 'Spend',
#  432: 'Thoroughly',
#  433: 'There',
#  434: 'top',
#  435: 'reasonably',
#  436: 'Luke',
#  437: 'Phoenix',
#  438: 'you',
#  439: 'slow',
#  440: 'old',
#  441: 'end',
#  442: 'mein',
#  443: 'Poor',
#  444: 'airline',
#  445: 'much',
#  446: 'sound',
#  447: 'suggestions',
#  448: 'mall',
#  449: 'drink',
#  450: 'ranch',
#  451: 'Great',
#  452: 'GO',
#  453: 'Noca',
#  454: 'highly',
#  455: 'Update',
#  456: 'inviting',
#  457: '..there',
#  458: 'grilled',
#  459: 'cheap',
#  460: 'slaw',
#  461: 'wow',
#  462: 'server',
#  463: 'sugar',
#  464: 'fondue',
#  465: 'anymore',
#  466: 'non-fancy',
#  467: 'possible',
#  468: 'huevos',
#  469: 'instantly',
#  470: 'crazy',
#  471: 'promise',
#  472: 'occasions',
#  473: 'just',
#  474: '?',
#  475: 'flavor',
#  476: 'strings',
#  477: 'before',
#  478: 'pulled',
#  479: 'Ians',
#  480: 'portions',
#  481: '1979',
#  482: 'quaint',
#  483: 'frozen',
#  484: 'dedicated',
#  485: 'absolutely',
#  486: 'ball',
#  487: 'Pizza',
#  488: 'serve',
#  489: 'why',
#  490: 'specials',
#  491: 'Hawaiian',
#  492: 'tater',
#  493: 'saganaki',
#  494: 'uploaded',
#  495: 'glass',
#  496: 'salt',
#  497: 'she',
#  498: 'bamboo',
#  499: 'NONE',
#  500: 'week',
#  501: 'mouths',
#  502: 'wish',
#  503: 'cow',
#  504: 'Green',
#  505: 'disaster',
#  506: 'blows',
#  507: 'imagination',
#  508: 'sad',
#  509: 'Rock',
#  510: 'evening',
#  511: 'worse',
#  512: 'foods',
#  513: 'Ironman',
#  514: 'lover',
#  515: 'rave',
#  516: 'limited',
#  517: 'juice..',
#  518: 'perfect',
#  519: 'brick',
#  520: 'freaking',
#  521: 'Really',
#  522: 'vanilla',
#  523: 'water',
#  524: 'spots',
#  525: 'To',
#  526: 'typical',
#  527: 'figured',
#  528: 'Took',
#  529: 'gyros',
#  530: 'walls',
#  531: 'refrained',
#  532: 'beautiful',
#  533: 'what',
#  534: 'usual',
#  535: 'letdown',
#  536: 'expanded',
#  537: 'reminded',
#  538: 'occasional',
#  539: 'Appetite',
#  540: 'yummy',
#  541: 'mouth',
#  542: 'HAVE',
#  543: 'OWNERS',
#  544: 'dog',
#  545: 'elegantly',
#  546: 'untoasted',
#  547: 'Phenomenal',
#  548: 'showed',
#  549: 'no',
#  550: 'dead',
#  551: 'FLY',
#  552: 'meh',
#  553: 'Anyway',
#  554: 'powdered',
#  555: 'disgrace',
#  556: 'holiday',
#  557: 'cuisine',
#  558: 'larger',
#  559: 'Fantastic',
#  560: 'Taco',
#  561: 'quit',
#  562: 'Mediocre',
#  563: 'poisoning',
#  564: 'selection',
#  565: 'hard',
#  566: 'classic',
#  567: 'law',
#  568: 'grandmother',
#  569: 'tasteless',
#  570: 'wonderful',
#  571: 'Steak',
#  572: 'Dog',
#  573: '1.5lb',
#  574: 'ourselves',
#  575: 'Khao',
#  576: 'leftover',
#  577: 'night',
#  578: 'idea',
#  579: 'prime',
#  580: 'croutons',
#  581: 'so',
#  582: 'Level',
#  583: 'oysters',
#  584: 'somehow',
#  585: 'accident',
#  586: 'truly',
#  587: 'Prices',
#  588: 'i',
#  589: 'FLAVOR',
#  590: 'grow',
#  591: 'location',
#  592: 'delights',
#  593: 'salty',
#  594: 'Chinese',
#  595: 'vegetables',
#  596: 'flat-lined',
#  597: 'seems',
#  598: 'terrific',
#  599: 'choose',
#  600: 'fail',
#  601: 'away',
#  602: 'boyfriend',
#  603: 'worst',
#  604: 'mary',
#  605: 'nut',
#  606: 'extensive',
#  607: 'ensued',
#  608: 'accordingly',
#  609: 'Costco',
#  610: 'checked',
#  611: 'killer',
#  612: 'need',
#  613: 'have',
#  614: 'apparently',
#  615: 'rubber',
#  616: 'martini',
#  617: 'atmosphere.1',
#  618: 'wanted',
#  619: 'hostess',
#  620: 'understand',
#  621: 'discount',
#  622: 'Indian',
#  623: 'rich',
#  624: 'passed',
#  625: 'equally',
#  626: 'fear',
#  627: 'stir',
#  628: 'arrives',
#  629: 'edible',
#  630: 'RUDE',
#  631: 'bird',
#  632: 'feeling',
#  633: 'NASTY',
#  634: 'sause',
#  635: 'not',
#  636: 'over-whelm',
#  637: 'expected',
#  638: 'roasted',
#  639: 'bits',
#  640: 'Disappointed',
#  641: 'pricing',
#  642: 'give',
#  643: 'lawyers',
#  644: 'nice',
#  645: 'Plus',
#  646: 'gyro',
#  647: 'drag',
#  648: 'treated',
#  649: 'group',
#  650: 'UNREAL',
#  651: 'past',
#  652: 'long',
#  653: 'once',
#  654: 'biscuits',
#  655: 'complete',
#  656: 'Vegetarian',
#  657: 'Egg',
#  658: 'value',
#  659: 'WAY',
#  660: 'obviously',
#  661: 'events',
#  662: 'vegan/veggie',
#  663: '.the',
#  664: 'attention',
#  665: '%',
#  666: 'seriously',
#  667: 'unprofessional',
#  668: 'hours',
#  669: 'nearly',
#  670: 'Pita',
#  671: 'cocktail',
#  672: 'prepare',
#  673: 'Delight',
#  674: 'Fridays',
#  675: 'soooooo',
#  676: 'visited',
#  677: 'deeply',
#  678: 'hottest',
#  679: 'needed',
#  680: 'house',
#  681: 'Then',
#  682: 'worth',
#  683: 'excellent',
#  684: 'dispenser',
#  685: 'SCREAMS',
#  686: 'rarely',
#  687: 'accountant',
#  688: 'while',
#  689: 'being',
#  690: 'Bussell',
#  691: 'Seriously',
#  692: 'selections',
#  693: 'liking',
#  694: 'Hands',
#  695: 'crêpe',
#  696: 'stepped',
#  697: 'unwrapped',
#  698: 'meat',
#  699: 'slices',
#  700: 'disagree',
#  701: 'space',
#  702: 'sick',
#  703: 'interesting',
#  704: 'Breeze',
#  705: 'name',
#  706: 'Everyone',
#  707: 'likes',
#  708: 'Crema',
#  709: 'Unfortunately',
#  710: 'falafels',
#  711: 'beers',
#  712: 'FREEZING',
#  713: 'expect',
#  714: 'Back',
#  715: 'incredible',
#  716: 'marrow',
#  717: 'proclaimed',
#  718: 'dining',
#  719: 'charming',
#  720: 'block',
#  721: 'bites',
#  722: 'curry',
#  723: 'anything',
#  724: 'tailored',
#  725: 'Kind',
#  726: '..ohhh',
#  727: 'insulted',
#  728: 'Caballero',
#  729: 'first',
#  730: 'few',
#  731: 'fresh',
#  732: 'soundtrack',
#  733: 'DELICIOUS',
#  734: 'treat',
#  735: 'Magic',
#  736: 'burgers',
#  737: 'beer',
#  738: 'Cute',
#  739: 'exceptional',
#  740: 'had',
#  741: 'half',
#  742: 'Wo',
#  743: 'provides',
#  744: 'wontons',
#  745: 'overall',
#  746: 'mains',
#  747: 'must-stop',
#  748: 'Veggitarian',
#  749: 'FANTASTIC',
#  750: 'color',
#  751: 'satisfied',
#  752: 'every',
#  753: 'Halibut',
#  754: 'One',
#  755: 'gluten',
#  756: 'food/service',
#  757: 'seasoning',
#  758: 'courteous',
#  759: 'Yeah',
#  760: 'worker',
#  761: 'peanuts',
#  762: 'cost',
#  763: 'look',
#  764: '35',
#  765: 'been-stepped-in-and-tracked-everywhere',
#  766: 'carpaccio',
#  767: 'turkey',
#  768: 'live',
#  769: 'hoping',
#  770: 'dried',
#  771: 'Cod',
#  772: 'very',
#  773: '100',
#  774: 'chicken',
#  775: 'restaurants',
#  776: 'excuse',
#  777: 'Area',
#  778: 'section',
#  779: 'clue',
#  780: 'fiancé',
#  781: 'AND',
#  782: 'extremely',
#  783: 'reading',
#  784: 'spice',
#  785: 'place',
#  786: 'particular',
#  787: 'pastry',
#  788: 'bartender',
#  789: 'etc',
#  790: 'gold',
#  791: 'papers',
#  792: 'drive',
#  793: 'affordable',
#  794: 'Based',
#  795: 'part',
#  796: 'since',
#  797: 'REALLY',
#  798: 'find',
#  799: 'neighborhood',
#  800: 'hand',
#  801: 'Could',
#  802: 'says',
#  803: 'fuzzy',
#  804: 'rudely',
#  805: 'friend',
#  806: 'packed',
#  807: 'break',
#  808: 'running',
#  809: 'Del',
#  810: 'reservation',
#  811: 'third',
#  812: 'Maine',
#  813: 'Wienerschnitzel',
#  814: 'Overpriced',
#  815: 'spotty',
#  816: 'mouthful',
#  817: 'Maria',
#  818: 'THIS',
#  819: 'cooking',
#  820: 'email',
#  821: 'middle',
#  822: 'missing',
#  823: 'cover',
#  824: 'daily',
#  825: 'Service-check',
#  826: 'funny',
#  827: 'A',
#  828: 'After',
#  829: 'close',
#  830: 'fries',
#  831: 'held',
#  832: 'AN',
#  833: 'NOT',
#  834: 'fry',
#  835: 'pasta',
#  836: 'capers',
#  837: 'refried',
#  838: 'companions',
#  839: 'closed',
#  840: 'bloodiest',
#  841: 'crepe',
#  842: '/hand',
#  843: 'inexpensive',
#  844: 'upgrading',
#  845: 'rinse',
#  846: 'up',
#  847: 'apologize',
#  848: 'Soi',
#  849: 'these',
#  850: 'plus',
#  851: 'send',
#  852: 'mussels',
#  853: 'black',
#  854: 'experience',
#  855: 'go',
#  856: 'wall',
#  857: 'under-services',
#  858: 'auju',
#  859: 'giant',
#  860: 'blandest',
#  861: 'Check',
#  862: 'bread',
#  863: 'meet',
#  864: 'peas',
#  865: 'dish',
#  866: 'although',
#  867: 'sucked',
#  868: 'tenders',
#  869: 'vibe',
#  870: 'legit',
#  871: 'bagels',
#  872: 'Waited',
#  873: 'fabulous',
#  874: 'raspberry',
#  875: 'condiment',
#  876: 'warnings',
#  877: 'customers',
#  878: 'please',
#  879: 'served',
#  880: 'oh',
#  881: 'Sprouts',
#  882: 'finish',
#  883: 'gross',
#  884: 'Baseball',
#  885: 'teeth',
#  886: 'Rick',
#  887: 'Blah',
#  888: 'stop',
#  889: 'we',
#  890: 'starving',
#  891: 'out',
#  892: 'today',
#  893: 'tea',
#  894: 'smaller',
#  895: 'got',
#  896: 'time',
#  897: 'until',
#  898: 'surprise',
#  899: 'piano',
#  900: 'said',
#  901: 'lot',
#  902: '-My',
#  903: 'Seat',
#  904: 'stupid',
#  905: 'would',
#  906: 'negligent',
#  907: 'satifying',
#  908: 'bit',
#  909: 'who',
#  910: 'hour',
#  911: 'burned',
#  912: 'pepper',
#  913: 'be',
#  914: 'probably',
#  915: 'serivce',
#  916: 'imagine',
#  917: 'felt',
#  918: 'properly',
#  919: 'charcoal',
#  920: 'bellies',
#  921: 'kind',
#  922: 'zero',
#  923: 'connoisseur',
#  924: 'comfortable',
#  925: 'spot',
#  926: 'highlighted',
#  927: 'cook',
#  928: 'But',
#  929: 'colder',
#  930: 'talk',
#  931: 'coffee',
#  932: 'Paradise',
#  933: 'plain',
#  934: 'low',
#  935: 'sub-par',
#  936: 'opinion',
#  937: 'humiliated',
#  938: 'Sat',
#  939: 'OVERPRICED',
#  940: 'crisp',
#  941: 'char',
#  942: 'horrible',
#  943: 'Very',
#  944: '8',
#  945: 'summarize',
#  946: 'Friend',
#  947: 'people',
#  948: 'memory',
#  949: 'providing',
#  950: 'beans',
#  951: 'should',
#  952: 'opposed',
#  953: 'here',
#  954: 'Experience',
#  955: 'steakhouse',
#  956: 'Long',
#  957: 'downside',
#  958: 'especially',
#  959: 'Disappointing',
#  960: 'too',
#  961: 'modern',
#  962: 'left',
#  963: 'Nice',
#  964: 'wasted',
#  965: 'truffle',
#  966: '.off',
#  967: 'wide',
#  968: 'extra',
#  969: 'complaints',
#  970: 'poor',
#  971: 'outdoor',
#  972: 'An',
#  973: 'Joey',
#  974: 'man',
#  975: 'WEAK',
#  976: 'largely',
#  977: 'least',
#  978: 'monster',
#  979: 'thru',
#  980: 'lettuce',
#  981: 'HOUR',
#  982: 'off',
#  983: 'lightly',
#  984: 'beat',
#  985: 'extraordinary',
#  986: 'Lordy',
#  987: 'ESTABLISHMENT',
#  988: 'Hard',
#  989: 'ratio',
#  990: 'greens',
#  991: 'Bland',
#  992: 'red',
#  993: 'Cape',
#  994: '*',
#  995: 'Bellagio',
#  996: 'disgust',
#  997: 'nicest',
#  998: 'fare',
#  999: 'flavorful',
#  ...}

# %% [markdown]
# ## 轉換句子為bag of words型式

# %%
def _get_bag_of_words_vector(sentence, word_index_dic, whole_words):
    sentence = sentence
    vector = np.zeros(len(whole_words))
    for word in nltk.word_tokenize(sentence):
        if word in whole_words:
            vector[word_index_dic[word]] += 1
    return vector

# %%
_get_bag_of_words_vector('Wow... Loved this place.', word_index, whole_words)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])
